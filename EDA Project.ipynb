# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("data.csv")
df
# Out:
#     Age  Gender         Education_Stage  Family_Annual_Income Internet_Access  \
# 0    11    Male          Live on campus             27.028267              No
# 1    11  Female               secondary             23.437475              No
# 2    13  Female          Live on campus             24.293795             Yes
# 3    13    Male              Key school             27.928872              No
# 4    17  Female              Key school             30.870981              No
# ..  ...     ...                     ...                   ...             ...
# 95   13  Female  vocational high school             25.741004              No
# 96   14  Female  vocational high school             25.226476             Yes
# 97   11    Male               Key class             27.575059              No
# 98   10  Female     general high school             26.019443             Yes
# 99   11    Male               secondary             24.556240             Yes
#
# ...

# %%
df.head(5)
# Out:
#    Age  Gender Education_Stage  Family_Annual_Income Internet_Access  \
# 0   11    Male  Live on campus             27.028267              No
# 1   11  Female       secondary             23.437475              No
# 2   13  Female  Live on campus             24.293795             Yes
# 3   13    Male      Key school             27.928872              No
# 4   17  Female      Key school             30.870981              No
#
#   Phone_Access  Mobile _Addiction_Score  Depression_Score  \
# 0       others                        2                 2
# 1  child's own                        1                 2
# 2      parents                        1                 2
# 3  child's own                        3                 3
# 4  child's own                        4                 4
#
#    Family_Functioning_Score  Academic_Rank\n  Learning_Burnout_Score
# 0                         2                2                       2
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education_Stage', 'Family_Annual_Income',
#        'Internet_Access', 'Phone_Access', 'Mobile _Addiction_Score',
#        'Depression_Score', 'Family_Functioning_Score', 'Academic_Rank\n',
#        'Learning_Burnout_Score'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Age  Family_Annual_Income  Mobile _Addiction_Score  \
# count  100.000000            100.000000                100.00000
# mean    12.110000             27.135498                  2.95000
# std      2.206029              2.373548                  1.37345
# min      7.000000             20.648232                  1.00000
# 25%     11.000000             25.501122                  2.00000
# 50%     12.000000             27.063642                  3.00000
# 75%     14.000000             28.496199                  4.00000
# max     17.000000             31.814201                  5.00000
#
#        Depression_Score  Family_Functioning_Score  Academic_Rank\n  \
# count        100.000000                 100.00000        100.00000
# mean           2.490000                   2.95000          2.95000
# std            1.077736                   1.37345          1.37345
# min            1.000000                   1.00000          1.00000
# ...

# %%
df.size
# Out:
# 1100

# %%
df.shape
# Out:
# (100, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       100 non-null    int64
#  1   Gender                    100 non-null    object
#  2   Education_Stage           100 non-null    object
#  3   Family_Annual_Income      100 non-null    float64
#  4   Internet_Access           100 non-null    object
#  5   Phone_Access              100 non-null    object
#  6   Mobile _Addiction_Score   100 non-null    int64
#  7   Depression_Score          100 non-null    int64
#  8   Family_Functioning_Score  100 non-null    int64
#  9   Academic_Rank
#             100 non-null    int64
#  10  Learning_Burnout_Score    100 non-null    int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 8.7+ KB

# %%
df.isna()
# Out:
#       Age  Gender  Education_Stage  Family_Annual_Income  Internet_Access  \
# 0   False   False            False                 False            False
# 1   False   False            False                 False            False
# 2   False   False            False                 False            False
# 3   False   False            False                 False            False
# 4   False   False            False                 False            False
# ..    ...     ...              ...                   ...              ...
# 95  False   False            False                 False            False
# 96  False   False            False                 False            False
# 97  False   False            False                 False            False
# 98  False   False            False                 False            False
# 99  False   False            False                 False            False
#
#     Phone_Access  Mobile _Addiction_Score  Depression_Score  \
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education_Stage, Family_Annual_Income, Internet_Access, Phone_Access, Mobile _Addiction_Score, Depression_Score, Family_Functioning_Score, Academic_Rank
# , Learning_Burnout_Score]
# Index: []

# %%
df[df.duplicated()].shape
# Out:
# (0, 11)

# %%
df['Education_Stage'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.corr()
# Out:
#                                Age  Family_Annual_Income  \
# Age                       1.000000             -0.032791
# Family_Annual_Income     -0.032791              1.000000
# Mobile _Addiction_Score   0.085179             -0.023663
# Depression_Score          0.142794             -0.000318
# Family_Functioning_Score  0.085179             -0.023663
# Academic_Rank\n           0.085179             -0.023663
# Learning_Burnout_Score    0.085179             -0.023663
#
#                           Mobile _Addiction_Score  Depression_Score  \
# Age                                      0.085179          0.142794
# Family_Annual_Income                    -0.023663         -0.000318
# Mobile _Addiction_Score                  1.000000          0.105431
# Depression_Score                         0.105431          1.000000
# Family_Functioning_Score                 1.000000          0.105431
# Academic_Rank\n                          1.000000          0.105431
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Education_Stage             0
# Family_Annual_Income        0
# Internet_Access             0
# Phone_Access                0
# Mobile _Addiction_Score     0
# Depression_Score            0
# Family_Functioning_Score    0
# Academic_Rank\n             0
# Learning_Burnout_Score      0
# dtype: int64

# %%
df[df.Gender=='Male']
# Out:
#     Age Gender         Education_Stage  Family_Annual_Income Internet_Access  \
# 0    11   Male          Live on campus             27.028267              No
# 3    13   Male              Key school             27.928872              No
# 5    13   Male          Live on campus             29.901900             Yes
# 7    10   Male               Key class             27.198778             Yes
# 8    10   Male     general high school             28.453150              No
# 9    10   Male               Key class             28.642345              No
# 11   13   Male  vocational high school             30.814604              No
# 13   11   Male              elementary             27.868111              No
# 15   13   Male               secondary             28.867951             Yes
# 18   14   Male              Key school             29.082416             Yes
# 19   16   Male              Key school             24.100603              No
# ...

# %%
len(df[df.Gender =='Male']) , len(df)
# Out:
# (43, 100)

# %%
df[df.Gender =='Female']
# Out:
#     Age  Gender         Education_Stage  Family_Annual_Income Internet_Access  \
# 1    11  Female               secondary             23.437475              No
# 2    13  Female          Live on campus             24.293795             Yes
# 4    17  Female              Key school             30.870981              No
# 6     8  Female               Key class             26.062608             Yes
# 10   11  Female               secondary             30.636575             Yes
# 12   12  Female               Key class             28.993254             Yes
# 14   14  Female              elementary             30.551922             Yes
# 16   15  Female              Key school             24.292362             Yes
# 17   15  Female              Key school             25.048729              No
# 22   10  Female     general high school             31.531962             Yes
# 23   10  Female  vocational high school             26.987944              No
# ...

# %%
len(df[df.Gender =='Female']),len(df)
# Out:
# (57, 100)

# %%
df.Depression_Score.value_counts()
# Out:
# 3    28
# 2    27
# 1    23
# 4    22
# Name: Depression_Score, dtype: int64

# %%
df.Family_Annual_Income.value_counts()
# Out:
# 27.028267    1
# 26.044942    1
# 29.202239    1
# 25.662177    1
# 31.085829    1
#             ..
# 23.331427    1
# 25.549114    1
# 24.702869    1
# 28.732563    1
# 24.556240    1
# Name: Family_Annual_Income, Length: 100, dtype: int64

# %%
df.Family_Functioning_Score.value_counts()
# Out:
# 3    27
# 1    20
# 2    18
# 5    18
# 4    17
# Name: Family_Functioning_Score, dtype: int64

# %%
df.Learning_Burnout_Score.value_counts()
# Out:
# 3    27
# 1    20
# 2    18
# 5    18
# 4    17
# Name: Learning_Burnout_Score, dtype: int64

# %%
df['Mobile _Addiction_Score'].value_counts()
# Out:
# 3    27
# 1    20
# 2    18
# 5    18
# 4    17
# Name: Mobile _Addiction_Score, dtype: int64

# %%
df.Age.value_counts()
# Out:
# 13    18
# 11    17
# 10    15
# 12    14
# 14    13
# 15     9
# 8      5
# 17     3
# 16     2
# 9      2
# 7      2
# Name: Age, dtype: int64

# %%
df['Academic_Rank\n'].value_counts()
# Out:
# 3    27
# 1    20
# 2    18
# 5    18
# 4    17
# Name: Academic_Rank\n, dtype: int64

# %%
df.Phone_Access.value_counts()
# Out:
# others         39
# parents        31
# child's own    30
# Name: Phone_Access, dtype: int64

# %%
df.Education_Stage.value_counts()
# Out:
# general high school       18
# Key class                 17
# Key school                16
# vocational high school    16
# secondary                 13
# Live on campus            11
# elementary                 9
# Name: Education_Stage, dtype: int64

# %%
df.Internet_Access	.value_counts()
# Out:
# Yes    52
# No     48
# Name: Internet_Access, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Female    57
# Male      43
# Name: Gender, dtype: int64

# %%
# Mobile Addiction Score v/s Internet Access Depecting Depression Score in Different colors

# %%
sns.barplot(y = 'Mobile _Addiction_Score',
            x = 'Internet_Access',
            hue = 'Depression_Score',
            data = df,
           
            ci = 0)
# Out:
# <AxesSubplot:xlabel='Internet_Access', ylabel='Mobile _Addiction_Score'>

# %%
# Mobile Addiction Score v/s Phone Access Depecting Depression Score in Different colors

# %%
sns.barplot(y = 'Mobile _Addiction_Score',
            x = 'Phone_Access',
            hue = 'Depression_Score',
            data = df,
            
            ci = 0)
# Out:
# <AxesSubplot:xlabel='Phone_Access', ylabel='Mobile _Addiction_Score'>

# %%
# Depression Score v/s Internet Access Depecting Gender in Different colors

# %%
sns.barplot(y = 'Depression_Score',
            x = 'Internet_Access',
            hue = 'Gender',
            data = df,
           
            ci = 0)
sns.set(rc={"figure.figsize":(8, 3)})

# %%
# Learning Burnout Score v/s Phone Access Depecting Depression Score in Different colors

# %%
sns.barplot(y = 'Learning_Burnout_Score',
            x = 'Phone_Access',
            hue = 'Depression_Score',
            data = df,

            ci = 0)
# Out:
# <AxesSubplot:xlabel='Phone_Access', ylabel='Learning_Burnout_Score'>

# %%
# Family Functioning Score v/s Phone Access Depecting Depression Score in Different colors

# %%
sns.barplot(y = 'Family_Functioning_Score',
            x = 'Phone_Access',
            hue = 'Depression_Score',
            data = df,
           
            ci = 0)
# Out:
# <AxesSubplot:xlabel='Phone_Access', ylabel='Family_Functioning_Score'>

# %%
# Family Anual Income v/s Education Stage Access Depecting Depression Score in Different colors

# %%
sns.barplot(y = 'Family_Annual_Income',
            x = 'Education_Stage',
            hue = 'Depression_Score',
            data = df,
            
            ci = 0)
sns.set(rc={"figure.figsize":(20, 4)})

# %%
# Family Annual Income v/s Gender Depecting Depression Score in Different colors

# %%
sns.set_style("whitegrid")
sns.pairplot(df,hue="Depression_Score" ,height = 4)
plt.show()

# %%
df.plot(kind='scatter',x='Education_Stage',y='Family_Annual_Income')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Education_Stage', ylabel='Family_Annual_Income'>

# %%
# Family Annual Income v/s Gender Depecting Depression Score in Different colors

# %%
df.plot(kind='scatter',x='Gender',y='Family_Annual_Income')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Gender', ylabel='Family_Annual_Income'>

# %%
df.Depression_Score.mean()
# Out:
# 2.49

# %%
df_depMean = df.Depression_Score > df.Depression_Score.mean()
df_depMean
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
#       ...
# 95    False
# 96    False
# 97     True
# 98    False
# 99     True
# Name: Depression_Score, Length: 100, dtype: bool

# %%
df_depMean.describe()
# Out:
# count       100
# unique        2
# top       False
# freq         50
# Name: Depression_Score, dtype: object

# %%
df_depMean = df[df.Depression_Score>df.Depression_Score.mean()]
df_depMean
# Out:
#     Age  Gender         Education_Stage  Family_Annual_Income Internet_Access  \
# 3    13    Male              Key school             27.928872              No
# 4    17  Female              Key school             30.870981              No
# 5    13    Male          Live on campus             29.901900             Yes
# 8    10    Male     general high school             28.453150              No
# 10   11  Female               secondary             30.636575             Yes
# 11   13    Male  vocational high school             30.814604              No
# 12   12  Female               Key class             28.993254             Yes
# 13   11    Male              elementary             27.868111              No
# 14   14  Female              elementary             30.551922             Yes
# 17   15  Female              Key school             25.048729              No
# 19   16    Male              Key school             24.100603              No
# ...

# %%
df_depMean.describe()
# Out:
#              Age  Family_Annual_Income  Mobile _Addiction_Score  \
# count  50.000000             50.000000                50.000000
# mean   12.440000             27.082381                 3.100000
# std     2.205374              2.504506                 1.265718
# min     7.000000             20.648232                 1.000000
# 25%    11.000000             25.437536                 2.000000
# 50%    13.000000             27.210046                 3.000000
# 75%    14.000000             28.582298                 4.000000
# max    17.000000             31.598487                 5.000000
#
#        Depression_Score  Family_Functioning_Score  Academic_Rank\n  \
# count         50.000000                 50.000000        50.000000
# mean           3.440000                  3.100000         3.100000
# std            0.501427                  1.265718         1.265718
# min            3.000000                  1.000000         1.000000
# ...

# %%
sns.barplot(y = 'Mobile _Addiction_Score',
            x = 'Internet_Access',
            hue = 'Depression_Score',
            data = df_depMean,
           
            ci = 0)
sns.set(rc={"figure.figsize":(10, 10)})

# %%
sns.barplot(y = 'Mobile _Addiction_Score',
            x = 'Phone_Access',
            hue = 'Depression_Score',
            data = df_depMean,
        
            ci = 0)
# Out:
# <AxesSubplot:xlabel='Phone_Access', ylabel='Mobile _Addiction_Score'>

# %%
df_depMean.Gender.value_counts()
# Out:
# Female    27
# Male      23
# Name: Gender, dtype: int64

# %%
df_mean_Females = df_depMean[(df_depMean.Gender=="Female") & (df_depMean.Internet_Access=="Yes")]
df_mean_Females
# Out:
#     Age  Gender         Education_Stage  Family_Annual_Income Internet_Access  \
# 10   11  Female               secondary             30.636575             Yes
# 12   12  Female               Key class             28.993254             Yes
# 14   14  Female              elementary             30.551922             Yes
# 41   14  Female               secondary             25.315580             Yes
# 49   11  Female     general high school             24.098305             Yes
# 51   13  Female              Key school             25.223435             Yes
# 55   14  Female               secondary             27.427022             Yes
# 59   13  Female     general high school             28.288247             Yes
# 64    7  Female  vocational high school             25.521555             Yes
# 79   11  Female               Key class             25.956217             Yes
# 80   12  Female               secondary             21.246961             Yes
# ...

# %%
df_mean_Females.Gender.value_counts()
# Out:
# Female    13
# Name: Gender, dtype: int64

# %%
df_mean_Females_No = df_depMean[(df_depMean.Gender=="Female") & (df_depMean.Internet_Access=="No")]
df_mean_Females_No
# Out:
#     Age  Gender         Education_Stage  Family_Annual_Income Internet_Access  \
# 4    17  Female              Key school             30.870981              No
# 17   15  Female              Key school             25.048729              No
# 23   10  Female  vocational high school             26.987944              No
# 33   16  Female               secondary             26.808719              No
# 35   15  Female               Key class             20.648232              No
# 42   11  Female          Live on campus             28.749132              No
# 57   15  Female     general high school             23.525338              No
# 65   12  Female              elementary             28.328965              No
# 67    9  Female              Key school             23.435924              No
# 72   11  Female          Live on campus             25.662177              No
# 73   13  Female  vocational high school             29.202239              No
# ...

# %%
df_mean_Females_No.Gender.value_counts()
# Out:
# Female    14
# Name: Gender, dtype: int64

# %%
df_mean_Males = df_depMean[(df_depMean.Gender=="Male") & (df_depMean.Internet_Access=="Yes")]
df_mean_Males
# Out:
#     Age Gender      Education_Stage  Family_Annual_Income Internet_Access  \
# 5    13   Male       Live on campus             29.901900             Yes
# 52   15   Male  general high school             26.124586             Yes
# 53   14   Male           elementary             23.829144             Yes
# 54    8   Male            Key class             27.218666             Yes
# 69   13   Male            secondary             25.439821             Yes
# 70   13   Male       Live on campus             25.436775             Yes
# 71   13   Male            Key class             31.085829             Yes
# 83    7   Male  general high school             27.201426             Yes
# 88   12   Male  general high school             25.102014             Yes
# 99   11   Male            secondary             24.556240             Yes
#
#    Phone_Access  Mobile _Addiction_Score  Depression_Score  \
# 5        others                        5                 4
# ...

# %%
df_mean_Males.Gender.value_counts()
# Out:
# Male    10
# Name: Gender, dtype: int64

# %%
df_mean_Males_No = df_depMean[(df_depMean.Gender=="Male") & (df_depMean.Internet_Access=="No")]
df_mean_Males_No
# Out:
#     Age Gender         Education_Stage  Family_Annual_Income Internet_Access  \
# 3    13   Male              Key school             27.928872              No
# 8    10   Male     general high school             28.453150              No
# 11   13   Male  vocational high school             30.814604              No
# 13   11   Male              elementary             27.868111              No
# 19   16   Male              Key school             24.100603              No
# 20   15   Male              elementary             30.673604              No
# 24   14   Male     general high school             27.067009              No
# 26   14   Male               Key class             28.163967              No
# 38   12   Male     general high school             27.501783              No
# 66   13   Male               Key class             26.989232              No
# 84   12   Male          Live on campus             28.625347              No
# ...

# %%
df_mean_Males_No.Gender.value_counts()
# Out:
# Male    13
# Name: Gender, dtype: int64

# %%
correlation_mat = df_mean_Females.corr()
sns.heatmap(correlation_mat, annot = True)
# Out:
# <AxesSubplot:>

# %%
correlation_mat = df.corr()
sns.heatmap(correlation_mat, annot = True)
# Out:
# <AxesSubplot:>

# %%
grouped_Gender_Age = df.groupby(['Age','Gender'])[["Academic_Rank\n","Learning_Burnout_Score","Depression_Score","Mobile _Addiction_Score"]].mean()

# %%
grouped_Gender_Age
# Out:
#             Academic_Rank\n  Learning_Burnout_Score  Depression_Score  \
# Age Gender
# 7   Female         3.000000                3.000000          3.000000
#     Male           5.000000                5.000000          3.000000
# 8   Female         3.750000                3.750000          1.750000
#     Male           1.000000                1.000000          3.000000
# 9   Female         3.000000                3.000000          2.500000
# 10  Female         2.400000                2.400000          2.100000
#     Male           3.200000                3.200000          1.800000
# 11  Female         2.100000                2.100000          2.400000
#     Male           2.285714                2.285714          2.571429
# 12  Female         3.428571                3.428571          2.857143
#     Male           2.857143                2.857143          2.142857
# 13  Female         3.111111                3.111111          2.333333
# ...

# %%
df.groupby(['Age','Gender'])[["Academic_Rank\n","Learning_Burnout_Score","Depression_Score","Mobile _Addiction_Score"]].aggregate(['min','max','median'])
# Out:
#            Academic_Rank\n            Learning_Burnout_Score             \
#                        min max median                    min max median
# Age Gender
# 7   Female               3   3    3.0                      3   3    3.0
#     Male                 5   5    5.0                      5   5    5.0
# 8   Female               3   5    3.5                      3   5    3.5
#     Male                 1   1    1.0                      1   1    1.0
# 9   Female               1   5    3.0                      1   5    3.0
# 10  Female               1   5    2.0                      1   5    2.0
#     Male                 1   5    4.0                      1   5    4.0
# 11  Female               1   3    2.0                      1   3    2.0
#     Male                 1   4    2.0                      1   4    2.0
# 12  Female               1   5    3.0                      1   5    3.0
#     Male                 1   4    3.0                      1   4    3.0
# ...

# %%
Conclusiion and Results :

The dataset we created from the survey questioneere which we collected from the people
consists of the following colums 'Age', 'Gender', 'Education_Stage', 'Family_Annual_Income',
   'Internet_Access', 'Phone_Access', 'Mobile _Addiction_Score',
   'Depression_Score', 'Family_Functioning_Score', 'Academic_Rank\n',
   'Learning_Burnout_Score'
    Out of which we concluded that 
    1. Females students have depression score more than average depression score
    2. Students who are more addicted to mobile phones but have no internet are more depressed
    3. Students who have their own mobiles are more depressed 
    4. Family_Annual_Income and Depression Score  have negative coreleation as 0.3 which implies as the family anual income score increases the depression score decreases
